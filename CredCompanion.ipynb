# %% [markdown]
# ## <center>CredCompanion</center>

# %% [markdown]
# This Jupyter Notebook will host all the code, calculations and data rendering that has been done to discuss the results in the PDF report.
#
#
# <a id='contents'></a>
# ## Table of Contents
# - [Library Import](#libraries)
# - [Function Definition - Define Credit Card Information](#credit_card_info)
# - [Function Definition - Define Optimization Model and Decision variables](#model_definition)
# - [Function Definition - Define and set Objective function](#objective_function)
# - [Function Definition - Define and add Constraints](#constraints_function)
# - [Function Definition - Wrapper function to create optimization model](#wrapper_function)
# - [Function Definition - Export output to excel](#output_function)
# - [Code Block - Import user information and extract credit card information](#user_code_block)
# - [Code Block - Declare the optimization model and run it](#declare_and_run)
# - [Code Block - Sensitivity Analysis](#sensitivity_analysis)
# - [Code Block - Store output in excel](#store_output)

# %% [markdown]
# <a id='libraries'></a>
# ## Library Import
# [Back to table of contents](#contents)

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import math
import tkinter as tk
from tkinter import filedialog
import datetime
from openpyxl import load_workbook

# %% [markdown]
# <a id='credit_card_info'></a>
# ## Function Definition - Define Credit Card Information
# [Back to table of contents](#contents)

# %%
def define_credit_card_information():
    
    cred_data_categories = ['Rewards','APR Cash Advance','APR Purchases','Bonus OTP without conditions',
                        'Bonus OTP with conditions','Bonus Rewards','Income level requirement','Annual Fees']
    cred_card_data = {}
    for cat in cred_data_categories:
        cred_card_data[cat] = pd.read_excel('Credit_Card_Data.xlsx',sheet_name = cat)
    
    #Let us define the cards in variable "i"
    i = cred_card_data['Rewards']['Card'].values

    #Let us define the categories in variable"j"
    j = ['Travel','Grocery','Restaurant','Fuel','Medical','Bills','Others']

    #Let us define the number of months as specified by the user in variable "k"
    k = np.arange(1,user_num_years*12+1)
    
    #Define the Cijk matrix in a dictionary
    C = {}
    data = cred_card_data['Rewards']
    for a,card in enumerate(i):
        for b,cat in enumerate(j):
            C[str(a+1)+ '_' + str(b+1)] = data[data['Card'] == card][cat].values[0]
    
    #Define the Bonus without conditions in a dictionary
    bonus_without_cond = {}
    data = cred_card_data['Bonus OTP without conditions']
    for a,card in enumerate(i):
        bonus_without_cond[str(a+1)] = data[data['Card']==card]['Amount'].values[0]
        
    #Define the Bonus with conditions in a dictionary
    bonus_with_cond = {}
    data = cred_card_data['Bonus OTP with conditions']
    for a,card in enumerate(i):
        bonus_with_cond[str(a+1)] = data[data['Card']==card]['Amount'].values[0]
    
    #Define the APR cash advance in a dictionary
    apr_cash_advance = {}
    data = cred_card_data['APR Cash Advance']
    for a,card in enumerate(i):
        for c in range(1,user_num_years+1):
            apr_cash_advance[str(a+1) + '_' + str(c)] = data[data['Card']==card][c].values[0]
        
    #Define the APR Purchases in a dictionary
    apr_purchases = {}
    data = cred_card_data['APR Purchases']
    for a,card in enumerate(i):
        for c in range(1,user_num_years+1):
            apr_purchases[str(a+1) + '_' + str(c)] = data[data['Card']==card][c].values[0]
            
    #Define the Bonus rewards in a dictionary
    bonus_rewards = {}
    data = cred_card_data['Bonus Rewards']
    for a,card in enumerate(i):
        for b,cat in enumerate(j):
            bonus_rewards[str(a+1)+ '_' + str(b+1)] = data[data['Card'] == card][cat].values[0]
    
    #Define the income requirement in a dictionary
    income_requirement_individual = {}
    income_requirement_combined = {}
    data = cred_card_data['Income level requirement']
    for a,card in enumerate(i):
        income_requirement_individual[str(a+1)] = data[data['Card']==card]['Individual Limit'].values[0]
        income_requirement_combined[str(a+1)] = data[data['Card']==card]['Combined Household Limit'].values[0]
    for key in income_requirement_individual.keys():
        if math.isnan(income_requirement_individual[key]):
            income_requirement_individual[key] = 1000000000
    for key in income_requirement_combined.keys():
        if math.isnan(income_requirement_combined[key]):
            income_requirement_combined[key] = 1000000000
            
    #Define the Annual Fees in a dictionary
    annual_fees = {}
    data = cred_card_data['Annual Fees']
    for a,card in enumerate(i):
        for c in range(1,user_num_years+1):
            annual_fees[str(a+1) + '_' + str(c)] = data[data['Card']==card][c].values[0]
            
    return i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,bonus_rewards,income_requirement_individual, income_requirement_combined,annual_fees

# %% [markdown]
# <a id='model_definition'></a>
# ## Function Definition - Define Optimization Model and Decision variables
# [Back to table of contents](#contents)

# %%
#Define and model and create the variables

def credcompanion_define(model_name,i,j,k,user_payments,user_loans):
    # Create a new model
    model_cred_companion = gp.Model(model_name)
    
    #Adding the Xijk variable for spending amounts
    X = {}
    for a in range(1,len(i)+1):
        for b in range(1,len(j)+1):
            for c in k:
                n = 'X_' + str(a) + '_' + str(b) + '_' + str(c)
                X[str(a) + '_' + str(b) + '_' + str(c)] = model_cred_companion.addVar(vtype=GRB.CONTINUOUS, name= n)
    model_cred_companion.update()
    
    #Adding the Yi variable for card selection
    Y = {}
    for a in range(1,len(i)+1):
        n = 'Y_' + str(a)
        Y[str(a)] = model_cred_companion.addVar(vtype=GRB.BINARY, name= n)
    model_cred_companion.update()
    
    #Adding the Y_APR_Purchase_i variable for card selection for APR purchases
    Y_APR_purchase = {}
    if user_payments == 'No':
        for a in range(1,len(i)+1):
            n = 'Y_APR_purchase_' + str(a)
            Y_APR_purchase[str(a)] = model_cred_companion.addVar(vtype=GRB.BINARY, name= n)
        model_cred_companion.update()
    
    #Adding the X_APR_Purchase_i variable for amounts for APR purchases in each card
    X_APR_purchase = {}
    if user_payments == 'No':
        for a in range(1,len(i)+1):
            for c in range(1,int(len(k)/12+1)):
                n = 'X_APR_purchase_' + str(a) + '_' + str(c)
                X_APR_purchase[str(a) + '_' + str(c)] = model_cred_companion.addVar(vtype=GRB.CONTINUOUS, name= n)
        model_cred_companion.update()
    
    #Adding the Y_APR_cash_i variable for card selection for APR cash advance
    Y_APR_cash = {}
    if user_loans == 'Yes':
        for a in range(1,len(i)+1):
            n = 'Y_APR_cash_' + str(a)
            Y_APR_cash[str(a)] = model_cred_companion.addVar(vtype=GRB.BINARY, name= n)
        model_cred_companion.update()
        
    #Adding the Zi variable for bonus inclusion with conditions
    Z = {}
    for a in range(1,len(i)+1):
        n = 'Z_' + str(a)
        Z[str(a)] = model_cred_companion.addVar(vtype=GRB.BINARY, name= n)

    #Adding Zi variable for additional bonus
    a = 11
    n = 'Z_' + str(a) + '_addnl'
    Z[str(a) + '_addnl'] = model_cred_companion.addVar(vtype=GRB.BINARY, name= n)    

    model_cred_companion.update()
    
    #Adding the Pi variable for individual income
    P = {}
    for a in range(1,len(i)+1):
        n = 'P_' + str(a)
        P[str(a)] = model_cred_companion.addVar(vtype=GRB.BINARY, name= n)
    model_cred_companion.update()
    
    #Adding the Qi variable for combined household income
    Q = {}
    for a in range(1,len(i)+1):
        n = 'Q_' + str(a)
        Q[str(a)] = model_cred_companion.addVar(vtype=GRB.BINARY, name= n)
    model_cred_companion.update()
    
    return model_cred_companion, X, Y, Y_APR_purchase,X_APR_purchase, Y_APR_cash, Z, P, Q

# %% [markdown]
# <a id='objective_function'></a>
# ## Function Definition - Define and set Objective function
# [Back to table of contents](#contents)

# %%
#Set the objective

def credcompanion_setobjective(model_cred_companion,i,j,k,X,Y,Y_APR_purchase,X_APR_purchase,Y_APR_cash,Z,bonus_without_cond,
                               bonus_with_cond,annual_fees,user_loans_amount,user_loans_months,apr_cash_advance,
                               user_payments_amount,user_payments_months,apr_purchases):
    #Add rewards from spending in objective
    obj = 0
    for a in range(1,len(i)+1):
        for b in range(1,len(j)+1):
            for c in k:
                obj = obj + X[str(a) + '_' + str(b) + '_' + str(c)] * C[str(a)+ '_' + str(b)] * Y[str(a)]
                
    #Add one time bonus without conditions in objective
    for a in range(1,len(i)+1):
        obj = obj + bonus_without_cond[str(a)]*Y[str(a)]
        
    #Add one time bonus with conditions in objective
    for a in range(1,len(i)+1):
        obj = obj + bonus_with_cond[str(a)]*Y[str(a)]*Z[str(a)]

    a = 11
    obj = obj + 100*Y[str(a)]*Z[str(a) + '_addnl']
    
    #Add yearly fees in objective
    for a in range(1,len(i)+1):
        for c in range(1,user_num_years+1):
            obj = obj - annual_fees[str(a) + '_' + str(c)]*Y[str(a)]
            
    #Add yearly APR cash advance fees
    if user_loans == 'Yes':
        for a in range(1,len(i)+1):
            for c in range(1,user_num_years+1):
                obj = obj - user_loans_amount * (pow((1 + apr_cash_advance[str(a) + '_' + str(c)]/1200),user_loans_months) - 1) * Y_APR_cash[str(a)]
        
    #Add yearly APR purchases fees
    if user_payments == 'No':
        for a in range(1,len(i)+1):
            for c in range(1,user_num_years+1):
                obj = obj - X_APR_purchase[str(a) + '_' + str(c)] * (pow((1 + apr_purchases[str(a) + '_' + str(c)]/1200),user_payments_months) - 1) * Y_APR_purchase[str(a)]
    
    model_cred_companion.setObjective(obj,GRB.MAXIMIZE)
    model_cred_companion.update()
    
    return model_cred_companion

# %% [markdown]
# <a id='constraints_function'></a>
# ## Function Definition - Define and add Constraints
# [Back to table of contents](#contents)

# %%
#Add the constraints

def credcompanion_setconstraints(model_cred_companion,i,j,k,X,Y,Y_APR_purchase,X_APR_purchase,Y_APR_cash,Z,P, Q,
                                 user_num_cards,user_loans,user_payments,user_payments_amount,
                                 user_grocery_min,user_grocery_max,
                                 user_restaurant_min,user_restaurant_max,
                                 user_bills_min,user_bills_max,
                                 user_fuel_min,user_fuel_max,
                                 user_travel_min, user_travel_max,
                                 user_drugs_min, user_drugs_max,
                                 user_others_min, user_others_max,
                                 income_requirement_individual, income_requirement_combined,
                                ):
    
    #Adding the Yi constraint
    y_constraint = 0
    for key in Y.keys():
        y_constraint = y_constraint + Y[key]
    model_cred_companion.addConstr(y_constraint <= user_num_cards, "number_of_cards_constraint")
    model_cred_companion.update()
    
    #Adding constraint for APR cash advance
    if user_loans == 'Yes':
        y_apr_cash_constraint = 0
        for key in Y_APR_cash.keys():
            y_apr_cash_constraint = y_apr_cash_constraint + Y_APR_cash[key]
        model_cred_companion.addConstr(y_apr_cash_constraint == 1, "apr_cash_constraint")
        model_cred_companion.update()
        
    #Adding constraint for APR cash advance and Yi relationship
    if user_loans == 'Yes':
        for key in Y_APR_cash.keys():
            model_cred_companion.addConstr(Y_APR_cash[key] <= Y[key], "Y_APR_Cash_" + str(key))
            model_cred_companion.update()
            
    #Adding constraint for APR purchase
    if user_payments == 'No':
        for c in range(1,user_num_years+1):
            x_apr_purchase_constraint = 0
            for a in range(1,len(i)+1):
                x_apr_purchase_constraint = x_apr_purchase_constraint + X_APR_purchase[str(a) + '_' + str(c)] * Y_APR_purchase[str(a)]
            model_cred_companion.addConstr(x_apr_purchase_constraint == user_payments_amount, "APR_purchase_constraint_" + str(a) + "_" + str(c))
        model_cred_companion.update()
        
    #Adding constraint for APR purchase amounts
    if user_payments == 'No':
        for a in range(1,len(i)+1):
            for temp in range(0,user_num_years):
                purchase_constraint = 0
                for c in range(temp*12+1,temp*12+13):
                    for b in range(1,len(j)+1):
                        purchase_constraint = purchase_constraint + X[str(a) + '_' + str(b) + '_' + str(c)]
                model_cred_companion.addConstr(purchase_constraint >= X_APR_purchase[str(a) + '_' + str(temp+1)] * Y_APR_purchase[str(a)] , "Y_APR_Purchase_Amount_Constraint_" + str(a) + '_' + str(temp+1))
        model_cred_companion.update()
        
    #Adding constraint for APR purchases and Yi relationship
    if user_payments == 'No':
        for a in range(1,len(i)+1):
            model_cred_companion.addConstr(Y_APR_purchase[key] <= Y[key], "Y_APR_Purchase_" + str(a))
            model_cred_companion.update()
            
    #Adding constraint for APR purchases cards and purchase amount relationship
    if user_payments == 'No':
        for a in range(1,len(i)+1):
            for c in range(1,user_num_years+1):
                model_cred_companion.addConstr(Y_APR_purchase[str(a)] <= X_APR_purchase[str(a) + '_' + str(c)], "X_Y_APR_Purchase_" + str(a) + "_" + str(c))
            model_cred_companion.update()
            
    #Adding the constraints for various items (min and max range constraints)
    #Adding groceries constraint
    b = j.index('Grocery') + 1
    for c in k:
        grocery_constraint = 0
        for a in range(1,len(i)+1):
            grocery_constraint = grocery_constraint + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
        model_cred_companion.addConstr(grocery_constraint >= user_grocery_min, "grocery_constraint_min_" + str(c))
        model_cred_companion.addConstr(grocery_constraint <= user_grocery_max, "grocery_constraint_max_" + str(c))
    model_cred_companion.update()
    #Adding restaurant constraint
    b = j.index('Restaurant') + 1
    for c in k:
        restaurant_constraint = 0
        for a in range(1,len(i)+1):
            restaurant_constraint = restaurant_constraint + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
        model_cred_companion.addConstr(restaurant_constraint >= user_restaurant_min, "restaurant_constraint_min_" + str(c))
        model_cred_companion.addConstr(restaurant_constraint <= user_restaurant_max, "restaurant_constraint_max_" + str(c))
    model_cred_companion.update()
    #Adding Bills constraint
    b = j.index('Bills') + 1
    for c in k:
        bills_constraint = 0
        for a in range(1,len(i)+1):
            bills_constraint = bills_constraint + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
        model_cred_companion.addConstr(bills_constraint >= user_bills_min, "bills_constraint_min_" + str(c))
        model_cred_companion.addConstr(bills_constraint <= user_bills_max, "bills_constraint_max_" + str(c))
    model_cred_companion.update()
    #Adding fuel constraint
    b = j.index('Fuel') + 1
    for c in k:
        fuel_constraint = 0
        for a in range(1,len(i)+1):
            fuel_constraint = fuel_constraint + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
        model_cred_companion.addConstr(fuel_constraint >= user_fuel_min, "fuel_constraint_min_" + str(c))
        model_cred_companion.addConstr(fuel_constraint <= user_fuel_max, "fuel_constraint_max_" + str(c))
    model_cred_companion.update()
    #Adding Travel constraint
    b = j.index('Travel') + 1
    for c in k:
        travel_constraint = 0
        for a in range(1,len(i)+1):
            travel_constraint = travel_constraint + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
        model_cred_companion.addConstr(travel_constraint >= user_travel_min, "travel_constraint_min_" + str(c))
        model_cred_companion.addConstr(travel_constraint <= user_travel_max, "travel_constraint_max_" + str(c))
    model_cred_companion.update()
    #Adding Medical constraint
    b = j.index('Medical') + 1
    for c in k:
        medical_constraint = 0
        for a in range(1,len(i)+1):
            medical_constraint = medical_constraint + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
        model_cred_companion.addConstr(medical_constraint >= user_drugs_min, "medical_constraint_min_" + str(c))
        model_cred_companion.addConstr(medical_constraint <= user_drugs_max, "medical_constraint_max_" + str(c))
    model_cred_companion.update()
    #Adding Other constraint
    b = j.index('Others') + 1
    for c in k:
        other_constraint = 0
        for a in range(1,len(i)+1):
            other_constraint = other_constraint + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
        model_cred_companion.addConstr(other_constraint >= user_others_min, "other_constraint_min_" + str(c))
        model_cred_companion.addConstr(other_constraint <= user_others_max, "other_constraint_max_" + str(c))
    model_cred_companion.update()
    
    #Adding income level constraint
    for a in range(1,len(i)+1):
        model_cred_companion.addConstr(user_income_individual >= income_requirement_individual[str(a)]*P[str(a)], "indi_income_constraint_" + str(a))
    for a in range(1,len(i)+1):
        model_cred_companion.addConstr(user_income_house >= income_requirement_combined[str(a)]*Q[str(a)], "comb_income_constraint_" + str(a))
    for a in range(1,len(i)+1):
        model_cred_companion.addConstr(Y[str(a)] <= P[str(a)]  + Q[str(a)], "overall_income_constraint_" + str(a))
    model_cred_companion.update()
    
    #Adding constraint to limit X to 0 if card not chosen
    for a in range(1,len(i)+1):
        for b in range(1,len(j)+1):
            for c in k:
                model_cred_companion.addConstr(X[str(a) + '_' + str(b) + '_' + str(c)] <= Y[str(a)] * 1000000000,"X_limiting_constraint_" + str(a) + '_' + str(b) + '_' + str(c))
    model_cred_companion.update()
    
    #Adding constraint for one time bonus with conditions

    #TD® Aeroplan® Visa Infinite Privilege* Credit Card
    a = 6
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,4):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 3000 * Z[str(a)], "bonus_with_condn_" + str(a))


    #TD First Class Travel®Visa Infinite* Card
    a = 7
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,4):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 1500 * Z[str(a)], "bonus_with_condn_" + str(a))


    #TD Platinum Travel Visa* Card
    a = 8
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,4):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 1000 * Z[str(a)], "bonus_with_condn_" + str(a))


    #Scotiabank Passport™ Visa Infinite* Card
    a = 11
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,4):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 1000 * Z[str(a)], "bonus_with_condn_" + str(a))

    #Scotiabank Passport™ Visa Infinite* Card (Additional bonus)
    a = 11
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,13):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 40000 * Z[str(a) + '_addnl'], "bonus_with_condn_" + str(a) + '_addnl')


    #Scotiabank Gold American Express® Card
    a = 12
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,4):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 1000 * Z[str(a)], "bonus_with_condn_" + str(a))


    #CIBC Aventura® Visa Infinite* Card
    a = 25
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,5):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 3000 * Z[str(a)], "bonus_with_condn_" + str(a))


    #CIBC Aventura® Visa Infinite Privilege* Card
    a = 29
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,5):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 3000 * Z[str(a)], "bonus_with_condn_" + str(a))


    #CIBC AEROPLAN® VISA INFINITE PRIVILEGE* CARD
    a = 30
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in k:
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 25000 * Z[str(a)], "bonus_with_condn_" + str(a))


    #CIBC Aventura® Gold Visa* Card
    a = 31
    spending_amount = 0
    for b in range(1,len(j)+1):
        for c in range(1,5):
            spending_amount = spending_amount + X[str(a) + '_' + str(b) + '_' + str(c)] * Y[str(a)]
    model_cred_companion.addConstr(spending_amount >= 3000 * Z[str(a)], "bonus_with_condn_" + str(a))
    model_cred_companion.update()
    
    return model_cred_companion

# %% [markdown]
# <a id='wrapper_function'></a>
# ## Function Definition - Wrapper function to create optimization model
# [Back to table of contents](#contents)

# %%
def credcompanion_calculate(modelname,i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                            bonus_rewards,annual_fees,
                            user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                            user_grocery_min,user_grocery_max,
                            user_restaurant_min,user_restaurant_max,
                            user_bills_min,user_bills_max,
                            user_fuel_min,user_fuel_max,
                            user_travel_min, user_travel_max,
                            user_drugs_min, user_drugs_max,
                            user_others_min, user_others_max,
                            income_requirement_individual, income_requirement_combined):
    #Define model
    model_cred_companion, X, Y, Y_APR_purchase,X_APR_purchase, Y_APR_cash, Z, P, Q = credcompanion_define(modelname,i,j,k,user_payments,user_loans)
    #Define objective
    model_cred_companion = credcompanion_setobjective(model_cred_companion,i,j,k,X,Y,Y_APR_purchase,X_APR_purchase,Y_APR_cash,Z,bonus_without_cond,
                               bonus_with_cond,annual_fees,user_loans_amount,user_loans_months,apr_cash_advance,
                               user_payments_amount,user_payments_months,apr_purchases)
    #Define constraints
    model_cred_companion = credcompanion_setconstraints(model_cred_companion,i,j,k,X,Y,Y_APR_purchase,X_APR_purchase,Y_APR_cash,Z,P, Q,
                                 user_num_cards,user_loans,user_payments,user_payments_amount,
                                 user_grocery_min,user_grocery_max,
                                 user_restaurant_min,user_restaurant_max,
                                 user_bills_min,user_bills_max,
                                 user_fuel_min,user_fuel_max,
                                 user_travel_min, user_travel_max,
                                 user_drugs_min, user_drugs_max,
                                 user_others_min, user_others_max,
                                 income_requirement_individual, income_requirement_combined
                                )
    return model_cred_companion,X,Y,Z,Y_APR_cash,Y_APR_purchase,X_APR_purchase

# %% [markdown]
# <a id='output_function'></a>
# ## Function Definition - Export Output to excel
# [Back to table of contents](#contents)

# %%
def credcompanion_output(file_path,model_cred_companion,i,j,k,X,Y,C,Z,bonus_without_cond,bonus_with_cond,user_num_years,
                         annual_fees,user_loans,user_payments,user_loans_amount,apr_cash_advance,user_loans_months,Y_APR_cash,
                        Y_APR_purchase,X_APR_purchase,apr_purchases,user_payments_months,
                        travel_statement,grocery_statement,restaurant_statement,fuel_statement,drugs_statement,
                     bills_statement,others_statement,loans_statement,payments_statement):
        
    temp = file_path.split('/')
    temp[len(temp)-1].split('.')[0]
    name = temp[len(temp)-1].split('.')[0] + "{:%Y_%b_%d_%H_%M_%S}".format(datetime.datetime.now()) + '.xlsx'
    
    #COVER PAGE
    
    outputcolumns = ['Description','Value']
    df_coverpage = pd.DataFrame(columns=outputcolumns)
    
    #Selected cards
    new_dict = {}
    new_dict['Description'] = "Selected Cards"
    temp = []
    for a in range(1,len(i)+1):
        if Y[str(a)].x != 0:
            temp.append(i[a-1])
    new_dict['Value'] = temp
    df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
    
    #Total Rewards
    new_dict = {}
    new_dict['Description'] = "Total Rewards"
    temp = 0
    for a in range(1,len(i)+1):
        for b in range(1,len(j)+1):
            for c in k:
                temp = temp + X[str(a) + '_' + str(b) + '_' + str(c)].x * C[str(a)+ '_' + str(b)] * Y[str(a)].x
    new_dict['Value'] = temp
    df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
    
    #Total Bonus
    new_dict = {}
    new_dict['Description'] = "Total Bonus"
    temp = 0
    #Add one time bonus without conditions
    for a in range(1,len(i)+1):
        temp = temp + bonus_without_cond[str(a)] * Y[str(a)].x
    #Add one time bonus with conditions
    for a in range(1,len(i)+1):
        temp = temp + bonus_with_cond[str(a)] * Y[str(a)].x * Z[str(a)].x
    new_dict['Value'] = temp
    df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
    
    #Total Annual Fees
    new_dict = {}
    new_dict['Description'] = "Total annual Fees on Selected Cards"
    temp = 0
    for a in range(1,len(i)+1):
        for c in range(1,user_num_years+1):
            temp = temp + annual_fees[str(a) + '_' + str(c)] * Y[str(a)].x
    new_dict['Value'] = temp
    df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
    
    #Selected card and value for APR cash advance
    if user_loans == 'Yes':
        new_dict = {}
        new_dict['Description'] = "Selected card for Cash Advance"
        temp = []
        for a in range(1,len(i)+1):
            if Y_APR_cash[str(a)].x != 0:
                temp.append(i[a-1])
        new_dict['Value'] = temp
        df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
        new_dict = {}
        new_dict['Description'] = "Total Cash Advance Interest"
        temp = 0
        for a in range(1,len(i)+1):
            for c in range(1,user_num_years+1):
                temp = temp + user_loans_amount * (pow((1 + apr_cash_advance[str(a) + '_' + str(c)]/1200),user_loans_months) - 1) * Y_APR_cash[str(a)].x
        new_dict['Value'] = temp
        df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
    
    #Selected card for APR purchases
    if user_payments == 'No':
        new_dict = {}
        new_dict['Description'] = "Selected card for Purchase Repayment Shortfalls"
        temp = []
        for a in range(1,len(i)+1):
            if Y_APR_purchase[str(a)].x != 0:
                temp.append(i[a-1])
        new_dict['Value'] = temp
        df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
        new_dict = {}
        new_dict['Description'] = "Total Purchase Repayment Interest"
        temp = 0
        for a in range(1,len(i)+1):
            for c in range(1,user_num_years+1):
                temp = temp + X_APR_purchase[str(a) + '_' + str(c)].x * (pow((1 + apr_purchases[str(a) + '_' + str(c)]/1200),user_payments_months) - 1) * Y_APR_purchase[str(a)].x
        new_dict['Value'] = temp
        df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
    
    
    #Total Overall Benefits - Cost
    new_dict = {}
    new_dict['Description'] = "Total Overall Benefit - Cost"
    new_dict['Value'] = model_cred_companion.objVal
    df_coverpage = df_coverpage.append(new_dict, ignore_index=True)
    
    df_coverpage.to_excel(name,sheet_name = "Results",index=False)
    
    
    
    book = load_workbook(name)
    writer = pd.ExcelWriter(name, engine='openpyxl') 
    writer.book = book
    
    
    #SPENDING AMOUNTS PAGE
    
    outputcolumns = ['Card','Category']
    for c in k:
        outputcolumns.append('Month ' + str(c))
    df_monthly_spending = pd.DataFrame(columns=outputcolumns)
    for a in range(1,len(i)+1):
        if Y[str(a)].x != 0:
            for b in range(1,len(j)+1):
                new_dict = {}
                new_dict['Card'] = i[a-1]
                new_dict['Category'] = j[b-1]
                for c in k:
                    new_dict['Month ' + str(c)] = X[str(a) + '_' + str(b) + '_' + str(c)].x
                df_monthly_spending = df_monthly_spending.append(new_dict, ignore_index=True)
    
    df_monthly_spending.to_excel(writer,sheet_name = "Spending_Amounts",index=False)
    writer.save()
    
    #APR PURCHASES AMOUNTS PAGE
    if user_payments == 'No':
        outputcolumns = ['Card']
        for c in range(1,user_num_years+1):
            outputcolumns.append('Year ' + str(c))
        df_apr_purchases = pd.DataFrame(columns=outputcolumns)
        for a in range(1,len(i)+1):
            if Y_APR_purchase[str(a)].x != 0:
                new_dict = {}
                new_dict['Card'] = i[a-1]
                for c in range(1,user_num_years+1):
                    new_dict['Year ' + str(c)] = X_APR_purchase[str(a) + '_' + str(c)].x
                df_apr_purchases = df_apr_purchases.append(new_dict, ignore_index=True)
        df_apr_purchases.to_excel(writer,sheet_name = "Purchase_Shortfall_Amounts",index=False)
        writer.save()
        
        
    #Sensitivity Analysis page
    outputcolumns = ['Category','Sensitivity Analysis']
    df_sensitivity = pd.DataFrame(columns=outputcolumns)
    df_sensitivity = df_sensitivity.append({'Category':'Travel','Sensitivity Analysis':travel_statement}, ignore_index=True)
    df_sensitivity = df_sensitivity.append({'Category':'Groceries','Sensitivity Analysis':grocery_statement}, ignore_index=True)
    df_sensitivity = df_sensitivity.append({'Category':'Restaurants','Sensitivity Analysis':restaurant_statement}, ignore_index=True)
    df_sensitivity = df_sensitivity.append({'Category':'Fuel','Sensitivity Analysis':fuel_statement}, ignore_index=True)
    df_sensitivity = df_sensitivity.append({'Category':'Drugs','Sensitivity Analysis':drugs_statement}, ignore_index=True)
    df_sensitivity = df_sensitivity.append({'Category':'Bills','Sensitivity Analysis':bills_statement}, ignore_index=True)
    df_sensitivity = df_sensitivity.append({'Category':'Others','Sensitivity Analysis':others_statement}, ignore_index=True)
    if user_loans == 'Yes':
        df_sensitivity = df_sensitivity.append({'Category':'Cash Advance','Sensitivity Analysis':loans_statement}, ignore_index=True)
    if user_payments == 'No':
        df_sensitivity = df_sensitivity.append({'Category':'Credit Repayment Shortfall','Sensitivity Analysis':payments_statement}, ignore_index=True)
    df_sensitivity.to_excel(writer,sheet_name = "Sensitivity_Analysis",index=False)
    writer.save()

# %% [markdown]
# <a id='user_code_block'></a>
# ## Code Block - Import user information and extract credit card information
# [Back to table of contents](#contents)

# %%
root = tk.Tk()
root.withdraw()

file_path = filedialog.askopenfilename()

# %% [markdown]
# We will extract the user information and assign variables to them

# %%
user_inputs = pd.read_excel(file_path)

user_inputs['S.No'] = user_inputs['S.No'].astype(str)

user_num_years = user_inputs[user_inputs['S.No'] == '1']['Response'].values[0]

user_num_cards = user_inputs[user_inputs['S.No'] == '2']['Response'].values[0]

user_travel_min = user_inputs[user_inputs['S.No'] == '3.a']['Response'].values[0]
user_travel_max = user_inputs[user_inputs['S.No'] == '3.a']['Unnamed: 3'].values[0]

user_grocery_min = user_inputs[user_inputs['S.No'] == '3.b']['Response'].values[0]
user_grocery_max = user_inputs[user_inputs['S.No'] == '3.b']['Unnamed: 3'].values[0]

user_restaurant_min = user_inputs[user_inputs['S.No'] == '3.c']['Response'].values[0]
user_restaurant_max = user_inputs[user_inputs['S.No'] == '3.c']['Unnamed: 3'].values[0]

user_fuel_min = user_inputs[user_inputs['S.No'] == '3.d']['Response'].values[0]
user_fuel_max = user_inputs[user_inputs['S.No'] == '3.d']['Unnamed: 3'].values[0]

user_drugs_min = user_inputs[user_inputs['S.No'] == '3.e']['Response'].values[0]
user_drugs_max = user_inputs[user_inputs['S.No'] == '3.e']['Unnamed: 3'].values[0]

user_bills_min = user_inputs[user_inputs['S.No'] == '3.f']['Response'].values[0]
user_bills_max = user_inputs[user_inputs['S.No'] == '3.f']['Unnamed: 3'].values[0]

user_others_min = user_inputs[user_inputs['S.No'] == '3.g']['Response'].values[0]
user_others_max = user_inputs[user_inputs['S.No'] == '3.g']['Unnamed: 3'].values[0]

user_payments = user_inputs[user_inputs['S.No'] == '4.a']['Response'].values[0]

user_payments_amount = user_inputs[user_inputs['S.No'] == '4.b']['Response'].values[0]

user_payments_months = user_inputs[user_inputs['S.No'] == '4.c']['Response'].values[0]

user_loans = user_inputs[user_inputs['S.No'] == '5.a']['Response'].values[0]

user_loans_amount = user_inputs[user_inputs['S.No'] == '5.b']['Response'].values[0]

user_loans_months = user_inputs[user_inputs['S.No'] == '5.c']['Response'].values[0]

user_income_individual = user_inputs[user_inputs['S.No'] == '6.a']['Response'].values[0]

user_income_house = user_inputs[user_inputs['S.No'] == '6.b']['Response'].values[0]

# %% [markdown]
# Next, we will import the credit card information sheet

# %%
i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,bonus_rewards,income_requirement_individual, income_requirement_combined,annual_fees = define_credit_card_information()

# %%
for a,b in enumerate(j):
    print(a+1,b)
# Out:
# 1 Travel
# 2 Grocery
# 3 Restaurant
# 4 Fuel
# 5 Medical
# 6 Bills
# 7 Others

# %%
for a,b in enumerate(i):
    print(a+1,b)
# Out:
# 1 TD® Aeroplan® Visa Infinite* Card
# 2 TD® Aeroplan® Visa Platinum* Card
# 3 TD Rewards Visa* Card
# 4 TD Cash Back Visa Infinite* Card
# 5 TD Cash Back Visa* Card
# 6 TD® Aeroplan® Visa Infinite Privilege* Credit Card
# 7 TD First Class Travel®Visa Infinite* Card
# 8 TD Platinum Travel Visa* Card
# 9 TD Emerald Flex Rate Visa Card
# 10 Scotia Momentum® Visa Infinite* Card
# 11 Scotiabank Passport™ Visa Infinite* Card
# 12 Scotiabank Gold American Express® Card
# 13 Scotia Momentum® Mastercard®* Credit Card
# 14 RBC Avion Visa Infinite
# 15 RBC Rewards+ Visa
# 16 RBC Cash Back Preferred World Elite Mastercard
# 17 RBC Cash Back Mastercard
# 18 RBC Visa Classic Low Rate Option
# 19 RBC Avion Visa Infinite Privilege
# 20 Signature RBC Rewards Visa
# 21 RBC Avion Visa Platinum
# 22 RBC Visa Platinum
# 23 RBC Rewards Visa Preferred
# 24 RBC RateAdvantage Visa
# 25 CIBC Aventura® Visa Infinite* Card
# 26 CIBC AEROPLAN® VISA INFINITE* CARD
# 27 CIBC Dividend® Visa Infinite* Card
# 28 CIBC Classic Visa* Card
# 29 CIBC Aventura® Visa Infinite Privilege* Card
# 30 CIBC AEROPLAN® VISA INFINITE PRIVILEGE* CARD
# 31 CIBC Aventura® Gold Visa* Card
# 32 CIBC AEROPLAN® VISA* CARD
# 33 CIBC Dividend Platinum® Visa* Card
# 34 CIBC Dividend® Visa* Card
# 35 CIBC Select Visa* Card
# 36 Scotia Momentum®  Visa* Card
# 37 Scotiabank SCENE®* Visa* Card
# 38 Scotiabank American Express® Card
# 39 Scotia Momentum® No-Fee Visa* Card
# 40 Scotiabank Platinum American Express® Card
# 41 ScotiaGold Passport®  Visa* Card
# 42 No Fee Scotiabank Value® Visa* Card
# 43 Scotiabank Value®  Visa* Card
# 44 BMO eclipse Visa Infinite Card
# 45 BMO eclipse Visa Infinite Privilege Card
# 46 BMO CashBack® Mastercard®*
# 47 BMO® Preferred Rate Mastercard®*
# 48 BMO World Elite®* Mastercard®*
# 49 BMO AIR MILES®† Mastercard®*
# 50 BMO® CashBack® World Elite®* Mastercard®*
# 51 BMO® AIR MILES®† World Elite®* Mastercard®*
# 52 BMO Rewards® Mastercard®*

# %% [markdown]
# <a id='declare_and_run'></a>
# ## Code Block - Declare the optimization model and run it
# [Back to table of contents](#contents)

# %% [markdown]
# We will now define the model and set the objective and constraints

# %%
model_cred_companion,X,Y,Z,Y_APR_cash,Y_APR_purchase,X_APR_purchase = credcompanion_calculate('Cred_Companion',i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                            bonus_rewards,annual_fees,
                            user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                            user_grocery_min,user_grocery_max,
                            user_restaurant_min,user_restaurant_max,
                            user_bills_min,user_bills_max,
                            user_fuel_min,user_fuel_max,
                            user_travel_min, user_travel_max,
                            user_drugs_min, user_drugs_max,
                            user_others_min, user_others_max,
                            income_requirement_individual, income_requirement_combined)
# Out:
# Using license file C:\Users\Manthan\gurobi.lic
# Academic license - for non-commercial use only - expires 2021-01-07

# %%
model_cred_companion.optimize()
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xce0c9083
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.15s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3557.0560604
# Found heuristic solution: objective 4427.3494736
#
# Root relaxation: objective -5.540286e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5540.2863328 5540.28633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.67 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5540.29 4427.35 3557.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.493421193248e+01, best bound 5.540286332806e+03, gap 7293.5339%

# %% [markdown]
# <a id='sensitivity_analysis'></a>
# ## Code Block - Sensitivity Analysis
# [Back to table of contents](#contents)

# %%
#Define the range for travel
if user_travel_min != user_travel_max:
    travel_spending_delta = int((user_travel_max - user_travel_min)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_travel_max,user_travel_min,-int(travel_spending_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_Travel_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,user_bills_max,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, delta,
                                user_drugs_min, user_drugs_max,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        travel_statement = "A better solution exists if the range of spending on travel is from " + str(user_travel_min) + " to " + str(new_max)
    else:
        travel_statement = "The current solution is optimal for any value spent on travel in the current selected range"
else:
    travel_statement = "The current solution is optimal for any value spent on travel in the current selected range"

# %%
#Define the range for groceries
if user_grocery_min != user_grocery_max:
    groceries_spending_delta = int((user_grocery_max - user_grocery_min)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_grocery_max,user_grocery_min,-int(groceries_spending_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_Groceries_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,delta,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,user_bills_max,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, user_travel_max,
                                user_drugs_min, user_drugs_max,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        grocery_statement = "A better solution exists if the range of spending on groceries is from " + str(user_grocery_min) + " to " + str(new_max)
    else:
        grocery_statement = "The current solution is optimal for any value spent on groceries in the current selected range"
else:
    grocery_statement = "The current solution is optimal for any value spent on groceries in the current selected range"
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xce0c9083
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3557.0560604
# Found heuristic solution: objective 4427.3494736
#
# Root relaxation: objective -5.540286e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5540.2863328 5540.28633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.43 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5540.29 4427.35 3557.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.493421193248e+01, best bound 5.540286332806e+03, gap 7293.5339%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xefb019b3
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3540.2560604
# Found heuristic solution: objective 4415.5894736
#
# Root relaxation: objective -5.527054e+03, 532 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5527.0535348 5527.05353  0.00%     -    1s
#
# Explored 1 nodes (532 simplex iterations) in 1.47 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5527.05 4415.59 3540.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.170141395260e+01, best bound 5.527053534826e+03, gap 8857.7421%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xc06f1e95
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3523.4560604
# Found heuristic solution: objective 4403.8294736
#
# Root relaxation: objective -5.513821e+03, 522 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5513.8207368 5513.82074  0.00%     -    1s
#
# Explored 1 nodes (522 simplex iterations) in 1.47 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5513.82 4403.83 3523.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.846861597272e+01, best bound 5.513820736846e+03, gap 11276.0639%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xf3aa2e8e
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3506.6560604
# Found heuristic solution: objective 4392.0694736
#
# Root relaxation: objective -5.500588e+03, 545 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5500.5879389 5500.58794  0.00%     -    1s
#
# Explored 1 nodes (545 simplex iterations) in 1.47 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5500.59 4392.07 3506.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.523581799285e+01, best bound 5.500587938866e+03, gap 15510.7854%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb9c67f4b
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.12s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3489.8560604
# Found heuristic solution: objective 4380.3094736
#
# Root relaxation: objective -5.487355e+03, 544 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    5487.3551409 5487.35514  0.00%     -    1s
#
# Explored 1 nodes (544 simplex iterations) in 1.48 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5487.36 4380.31 3489.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200302001297e+01, best bound 5.487355140886e+03, gap 24839.0999%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x8a3e01f5
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3473.0560604
# Found heuristic solution: objective 4368.5494736
#
# Root relaxation: objective -5.474122e+03, 523 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5474.1223429 5474.12234  0.00%     -    1s
#
# Explored 1 nodes (523 simplex iterations) in 1.57 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5474.12 4368.55 3473.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.770222033096e+00, best bound 5.474122342906e+03, gap 62317.1466%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xf68f25fa
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3456.2560604
# Found heuristic solution: objective 4356.7894736
#
# Root relaxation: objective -5.460890e+03, 526 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5460.8895449 5460.88954  0.00%     -    1s
#
# Explored 1 nodes (526 simplex iterations) in 1.49 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5460.89 4356.79 3456.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.462575946781e+00, best bound 5.460889544927e+03, gap 122470.7923%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x3b7e2a3b
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.12s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3439.4560604
# Found heuristic solution: objective 4345.0294736
#
# Root relaxation: objective -5.447657e+03, 504 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5447.6567469 5447.65675  0.00%     -    1s
#
# Explored 1 nodes (504 simplex iterations) in 1.65 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5447.66 4345.03 3439.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.769537392666e+01, best bound 5.447656746947e+03, gap 30885.7679%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x3326ddd7
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3422.6560604
# Found heuristic solution: objective 4333.2694736
#
# Root relaxation: objective -5.434424e+03, 516 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5434.4239490 5434.42395  0.00%     -    1s
#
# Explored 1 nodes (516 simplex iterations) in 1.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5434.42 4333.27 3422.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.092817190653e+01, best bound 5.434423948967e+03, gap 17671.1127%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x0f4cd711
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3405.8560604
# Found heuristic solution: objective 4321.5094736
#
# Root relaxation: objective -5.421191e+03, 506 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5421.1911510 5421.19115  0.00%     -    1s
#
# Explored 1 nodes (506 simplex iterations) in 1.67 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5421.19 4321.51 3405.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.416096988641e+01, best bound 5.421191150987e+03, gap 12375.9785%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x6a62a8f0
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3389.0560604
# Found heuristic solution: objective 4309.7494736
#
# Root relaxation: objective -5.407958e+03, 510 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5407.9583530 5407.95835  0.00%     -    1s
#
# Explored 1 nodes (510 simplex iterations) in 1.45 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5407.96 4309.75 3389.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.739376786629e+01, best bound 5.407958353007e+03, gap 9522.5533%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xa8d9cb08
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.14s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3372.2560604
# Found heuristic solution: objective 4297.9894736
#
# Root relaxation: objective -5.394726e+03, 523 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5394.7255550 5394.72556  0.00%     -    1s
#
# Explored 1 nodes (523 simplex iterations) in 1.63 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5394.73 4297.99 3372.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -7.062656584616e+01, best bound 5.394725555027e+03, gap 7738.3801%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xad923028
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.13s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3355.4560604
# Found heuristic solution: objective 4286.2294736
#
# Root relaxation: objective -5.381493e+03, 487 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5381.4927570 5381.49276  0.00%     -    1s
#
# Explored 1 nodes (487 simplex iterations) in 1.59 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5381.49 4286.23 3355.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.385936382604e+01, best bound 5.381492757047e+03, gap 6517.2831%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb95fdfac
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3338.6560604
# Found heuristic solution: objective 4274.4694736
#
# Root relaxation: objective -5.368260e+03, 499 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5368.2599591 5368.25996  0.00%     -    1s
#
# Explored 1 nodes (499 simplex iterations) in 1.67 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5368.26 4274.47 3338.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.709216180591e+01, best bound 5.368259959067e+03, gap 5629.0354%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x22d7ba2c
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3321.8560604
# Found heuristic solution: objective 4262.7094736
#
# Root relaxation: objective -5.355027e+03, 519 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5355.0271611 5355.02716  0.00%     -    1s
#
# Explored 1 nodes (519 simplex iterations) in 1.45 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5355.03 4262.71 3321.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.103249597858e+02, best bound 5.355027161088e+03, gap 4953.8673%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd6c8ee2d
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3305.0560604
# Found heuristic solution: objective 4250.9494736
#
# Root relaxation: objective -5.341794e+03, 500 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5341.7943631 5341.79436  0.00%     -    1s
#
# Explored 1 nodes (500 simplex iterations) in 1.72 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5341.79 4250.95 3305.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.235577577657e+02, best bound 5.341794363108e+03, gap 4423.3177%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd6926c44
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3288.2560604
# Found heuristic solution: objective 4239.1894736
#
# Root relaxation: objective -5.328562e+03, 495 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5328.5615651 5328.56157  0.00%     -    1s
#
# Explored 1 nodes (495 simplex iterations) in 1.69 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5328.56 4239.19 3288.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.367905557455e+02, best bound 5.328561565128e+03, gap 3995.4163%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x3ae4cf6e
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.08s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3271.4560604
# Found heuristic solution: objective 4227.4294736
#
# Root relaxation: objective -5.315329e+03, 502 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5315.3287671 5315.32877  0.00%     -    1s
#
# Explored 1 nodes (502 simplex iterations) in 1.48 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5315.33 4227.43 3271.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.500233537254e+02, best bound 5.315328767148e+03, gap 3643.0009%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x544e3ec3
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.15s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3254.6560604
# Found heuristic solution: objective 4215.6694736
#
# Root relaxation: objective -5.302096e+03, 493 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5302.0959692 5302.09597  0.00%     -    2s
#
# Explored 1 nodes (493 simplex iterations) in 2.87 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5302.1 4215.67 3254.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.632561517053e+02, best bound 5.302095969168e+03, gap 3347.7159%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xa9b9e22c
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3237.8560604
# Found heuristic solution: objective 4203.9094736
#
# Root relaxation: objective -5.288863e+03, 499 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5288.8631712 5288.86317  0.00%     -    1s
#
# Explored 1 nodes (499 simplex iterations) in 1.37 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5288.86 4203.91 3237.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.764889496852e+02, best bound 5.288863171188e+03, gap 3096.7107%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x098c6e0e
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3221.0560604
# Found heuristic solution: objective 4192.1494736
#
# Root relaxation: objective -5.275580e+03, 509 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5275.5798550 5275.57985  0.00%     -    1s
#
# Explored 1 nodes (509 simplex iterations) in 1.51 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5275.58 4192.15 3221.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.897722659033e+02, best bound 5.275579854970e+03, gap 2879.9530%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x8d9b5311
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.24s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3204.2560604
# Found heuristic solution: objective 4180.3894736
#
# Root relaxation: objective -5.262241e+03, 535 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5262.2409687 5262.24097  0.00%     -    2s
#
# Explored 1 nodes (535 simplex iterations) in 2.77 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5262.24 4180.39 3204.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.031111521836e+02, best bound 5.262240968690e+03, gap 2690.8183%

# %%
#Define the range for restaurants
if user_restaurant_min != user_restaurant_max:
    restaurant_spending_delta = int((user_restaurant_max - user_restaurant_min)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_restaurant_max,user_restaurant_min,-int(restaurant_spending_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_restaurant_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,delta,
                                user_bills_min,user_bills_max,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, user_travel_max,
                                user_drugs_min, user_drugs_max,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        restaurant_statement = "A better solution exists if the range of spending on restaurant is from " + str(user_restaurant_min) + " to " + str(new_max)
    else:
        restaurant_statement = "The current solution is optimal for any value spent on restaurant in the current selected range"
else:
    restaurant_statement = "The current solution is optimal for any value spent on restaurant in the current selected range"
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xce0c9083
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.13s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3557.0560604
# Found heuristic solution: objective 4427.3494736
#
# Root relaxation: objective -5.540286e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5540.2863328 5540.28633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.55 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5540.29 4427.35 3557.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.493421193248e+01, best bound 5.540286332806e+03, gap 7293.5339%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x51384c23
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3552.2560604
# Found heuristic solution: objective 4424.4694736
#
# Root relaxation: objective -5.535486e+03, 518 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5535.4863328 5535.48633  0.00%     -    2s
#
# Explored 1 nodes (518 simplex iterations) in 2.82 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5535.49 4424.47 3552.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.013421193248e+01, best bound 5.535486332806e+03, gap 7792.7048%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb18f763d
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3547.4560604
# Found heuristic solution: objective 4421.5894736
#
# Root relaxation: objective -5.530686e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5530.6863328 5530.68633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.36 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5530.69 4421.59 3547.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.533421193248e+01, best bound 5.530686332806e+03, gap 8365.2224%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xf7810016
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3542.6560604
# Found heuristic solution: objective 4418.7094736
#
# Root relaxation: objective -5.525886e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5525.8863328 5525.88633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.33 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5525.89 4418.71 3542.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.053421193248e+01, best bound 5.525886332806e+03, gap 9028.5344%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x36ce61b2
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.22s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3537.8560604
# Found heuristic solution: objective 4415.8294736
#
# Root relaxation: objective -5.521086e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    5521.0863328 5521.08633  0.00%     -    2s
#
# Explored 1 nodes (518 simplex iterations) in 2.75 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5521.09 4415.83 3537.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.573421193248e+01, best bound 5.521086332806e+03, gap 9806.0992%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x61913f16
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3533.0560604
# Found heuristic solution: objective 4412.9494736
#
# Root relaxation: objective -5.516286e+03, 530 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5516.2863328 5516.28633  0.00%     -    1s
#
# Explored 1 nodes (530 simplex iterations) in 1.36 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5516.29 4412.95 3533.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.093421193248e+01, best bound 5.516286332806e+03, gap 10730.2183%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x72302b93
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.14s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3528.2560604
# Found heuristic solution: objective 4410.0694736
#
# Root relaxation: objective -5.511486e+03, 528 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5511.4863328 5511.48633  0.00%     -    2s
#
# Explored 1 nodes (528 simplex iterations) in 2.38 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5511.49 4410.07 3528.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.613421193248e+01, best bound 5.511486332806e+03, gap 11846.6359%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xf00670da
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.21s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3523.4560604
# Found heuristic solution: objective 4407.1894736
#
# Root relaxation: objective -5.506686e+03, 528 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5506.6863328 5506.68633  0.00%     -    1s
#
# Explored 1 nodes (528 simplex iterations) in 1.56 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5506.69 4407.19 3523.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.133421193248e+01, best bound 5.506686332806e+03, gap 13222.3450%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xf0034ee8
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3518.6560604
# Found heuristic solution: objective 4404.3094736
#
# Root relaxation: objective -5.501886e+03, 528 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5501.8863328 5501.88633  0.00%     -    1s
#
# Explored 1 nodes (528 simplex iterations) in 1.44 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5501.89 4404.31 3518.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.653421193248e+01, best bound 5.501886332806e+03, gap 14959.5457%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x447ddefd
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.24s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3513.8560604
# Found heuristic solution: objective 4401.4294736
#
# Root relaxation: objective -5.497086e+03, 528 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5497.0863328 5497.08633  0.00%     -    3s
#
# Explored 1 nodes (528 simplex iterations) in 3.28 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5497.09 4401.43 3513.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.173421193248e+01, best bound 5.497086332806e+03, gap 17222.2714%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x983acfda
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3509.0560604
# Found heuristic solution: objective 4398.5494736
#
# Root relaxation: objective -5.492286e+03, 528 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5492.2863328 5492.28633  0.00%     -    1s
#
# Explored 1 nodes (528 simplex iterations) in 1.47 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5492.29 4398.55 3509.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.693421193248e+01, best bound 5.492286332806e+03, gap 20291.4870%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xbb80e973
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3504.2560604
# Found heuristic solution: objective 4395.6694736
#
# Root relaxation: objective -5.487486e+03, 525 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5487.4863328 5487.48633  0.00%     -    2s
#
# Explored 1 nodes (525 simplex iterations) in 2.83 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5487.49 4395.67 3504.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.213421193248e+01, best bound 5.487486332806e+03, gap 24691.8758%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x4d43d946
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.13s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3499.4560604
# Found heuristic solution: objective 4392.7894736
#
# Root relaxation: objective -5.482686e+03, 524 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5482.6863328 5482.68633  0.00%     -    1s
#
# Explored 1 nodes (524 simplex iterations) in 1.56 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5482.69 4392.79 3499.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.733421193248e+01, best bound 5.482686332806e+03, gap 31529.2795%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x07a82bc8
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3494.6560604
# Found heuristic solution: objective 4389.9094736
#
# Root relaxation: objective -5.477886e+03, 528 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5477.8863328 5477.88633  0.00%     -    1s
#
# Explored 1 nodes (528 simplex iterations) in 1.40 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5477.89 4389.91 3494.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.253421193248e+01, best bound 5.477886332806e+03, gap 43603.4762%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd4c5fea7
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3489.8560604
# Found heuristic solution: objective 4387.0294736
#
# Root relaxation: objective -5.473086e+03, 536 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5473.0863328 5473.08633  0.00%     -    1s
#
# Explored 1 nodes (536 simplex iterations) in 1.79 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5473.09 4387.03 3489.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.734211932478e+00, best bound 5.473086332806e+03, gap 70664.6284%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x7843f585
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.12s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3485.0560604
# Found heuristic solution: objective 4384.1494736
#
# Root relaxation: objective -5.468286e+03, 536 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5468.2863328 5468.28633  0.00%     -    1s
#
# Explored 1 nodes (536 simplex iterations) in 1.66 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5468.29 4384.15 3485.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.934211932477e+00, best bound 5.468286332806e+03, gap 186263.0323%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xc45fcc27
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3480.2560604
# Found heuristic solution: objective 4381.2694736
#
# Root relaxation: objective -5.463486e+03, 524 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5463.4863328 5463.48633  0.00%     -    2s
#
# Explored 1 nodes (524 simplex iterations) in 2.59 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5463.49 4381.27 3480.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.865788067523e+00, best bound 5.463486332806e+03, gap 292924.5940%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xef5f7e2b
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3475.4560604
# Found heuristic solution: objective 4378.3894736
#
# Root relaxation: objective -5.458686e+03, 524 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5458.6863328 5458.68633  0.00%     -    1s
#
# Explored 1 nodes (524 simplex iterations) in 1.43 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5458.69 4378.39 3475.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.665788067523e+00, best bound 5.458686332806e+03, gap 81991.0874%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x190010ce
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3470.6560604
# Found heuristic solution: objective 4375.5094736
#
# Root relaxation: objective -5.453886e+03, 524 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5453.8863328 5453.88633  0.00%     -    1s
#
# Explored 1 nodes (524 simplex iterations) in 1.38 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5453.89 4375.51 3470.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.146578806752e+01, best bound 5.453886332806e+03, gap 47666.6069%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x6edf8dd1
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.25s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3465.8560604
# Found heuristic solution: objective 4372.6294736
#
# Root relaxation: objective -5.449086e+03, 519 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5449.0863328 5449.08633  0.00%     -    2s
#
# Explored 1 nodes (519 simplex iterations) in 2.90 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5449.09 4372.63 3465.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.626578806752e+01, best bound 5.449086332806e+03, gap 33600.2910%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x9bca5665
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3461.0560604
# Found heuristic solution: objective 4369.7494736
#
# Root relaxation: objective -5.444286e+03, 537 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5444.2863328 5444.28633  0.00%     -    1s
#
# Explored 1 nodes (537 simplex iterations) in 1.31 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5444.29 4369.75 3461.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.106578806752e+01, best bound 5.444286332806e+03, gap 25944.2092%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xcb9083d7
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3456.2560604
# Found heuristic solution: objective 4366.8694736
#
# Root relaxation: objective -5.439486e+03, 525 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5439.4863328 5439.48633  0.00%     -    2s
#
# Explored 1 nodes (525 simplex iterations) in 2.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5439.49 4366.87 3456.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.586578806752e+01, best bound 5.439486332806e+03, gap 21129.6563%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x62df502a
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.22s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3451.4560604
# Found heuristic solution: objective 4363.9894736
#
# Root relaxation: objective -5.434686e+03, 541 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5434.6863328 5434.68633  0.00%     -    2s
#
# Explored 1 nodes (541 simplex iterations) in 2.59 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5434.69 4363.99 3451.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.066578806752e+01, best bound 5.434686332806e+03, gap 17822.3110%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x3c371974
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3446.6560604
# Found heuristic solution: objective 4361.1094736
#
# Root relaxation: objective -5.429886e+03, 520 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5429.8863328 5429.88633  0.00%     -    1s
#
# Explored 1 nodes (520 simplex iterations) in 1.42 seconds
# Thread count was 8 (of 8 available processors)
# Solution count 3: 5429.89 4361.11 3446.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.546578806752e+01, best bound 5.429886332806e+03, gap 15410.2092%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x8436344e
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.13s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3441.8560604
# Found heuristic solution: objective 4358.2294736
#
# Root relaxation: objective -5.425086e+03, 522 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5425.0863328 5425.08633  0.00%     -    3s
#
# Explored 1 nodes (522 simplex iterations) in 3.37 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5425.09 4358.23 3441.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.026578806752e+01, best bound 5.425086332806e+03, gap 13573.1905%

# %%
#Define the range for fuel
if user_fuel_min != user_fuel_max:
    fuel_spending_delta = int((user_fuel_max - user_fuel_min)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_fuel_max,user_fuel_min,-int(fuel_spending_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_fuel_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,user_bills_max,
                                user_fuel_min,delta,
                                user_travel_min, user_travel_max,
                                user_drugs_min, user_drugs_max,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        fuel_statement = "A better solution exists if the range of spending on fuel is from " + str(user_fuel_min) + " to " + str(new_max)
    else:
        fuel_statement = "The current solution is optimal for any value spent on fuel in the current selected range"
else:
    fuel_statement = "The current solution is optimal for any value spent on fuel in the current selected range"
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xce0c9083
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3557.0560604
# Found heuristic solution: objective 4427.3494736
#
# Root relaxation: objective -5.540286e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5540.2863328 5540.28633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5540.29 4427.35 3557.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.493421193248e+01, best bound 5.540286332806e+03, gap 7293.5339%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x94e06036
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3554.1760604
# Found heuristic solution: objective 4424.4694736
#
# Root relaxation: objective -5.536955e+03, 530 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5536.9552224 5536.95522  0.00%     -    2s
#
# Explored 1 nodes (530 simplex iterations) in 2.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5536.96 4424.47 3554.18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.160310156669e+01, best bound 5.536955222440e+03, gap 7632.8427%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x038a1bdc
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.24s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3551.2960604
# Found heuristic solution: objective 4421.5894736
#
# Root relaxation: objective -5.533624e+03, 533 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5533.6241121 5533.62411  0.00%     -    2s
#
# Explored 1 nodes (533 simplex iterations) in 2.21 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5533.62 4421.59 3551.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.827199120091e+01, best bound 5.533624112074e+03, gap 8005.2625%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xc8dc1581
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3548.4160604
# Found heuristic solution: objective 4418.7094736
#
# Root relaxation: objective -5.530293e+03, 542 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5530.2930017 5530.29300  0.00%     -    1s
#
# Explored 1 nodes (542 simplex iterations) in 1.36 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5530.29 4418.71 3548.42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.494088083512e+01, best bound 5.530293001708e+03, gap 8415.8885%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd4595821
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.14s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3545.5360604
# Found heuristic solution: objective 4415.8294736
#
# Root relaxation: objective -5.526962e+03, 543 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    5526.9618913 5526.96189  0.00%     -    1s
#
# Explored 1 nodes (543 simplex iterations) in 1.72 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5526.96 4415.83 3545.54
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.160977046934e+01, best bound 5.526961891343e+03, gap 8870.9178%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xbb846f15
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3542.6560604
# Found heuristic solution: objective 4412.9494736
#
# Root relaxation: objective -5.523631e+03, 535 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5523.6307810 5523.63078  0.00%     -    1s
#
# Explored 1 nodes (535 simplex iterations) in 1.71 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5523.63 4412.95 3542.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.827866010356e+01, best bound 5.523630780977e+03, gap 9377.9646%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb8da3e08
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3539.7760604
# Found heuristic solution: objective 4410.0694736
#
# Root relaxation: objective -5.520300e+03, 522 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5520.2996706 5520.29967  0.00%     -    1s
#
# Explored 1 nodes (522 simplex iterations) in 1.55 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5520.3 4410.07 3539.78
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.494754973777e+01, best bound 5.520299670611e+03, gap 9946.4892%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xcb90b16e
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3536.8960604
# Found heuristic solution: objective 4407.1894736
#
# Root relaxation: objective -5.516969e+03, 531 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5516.9685602 5516.96856  0.00%     -    1s
#
# Explored 1 nodes (531 simplex iterations) in 1.52 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5516.97 4407.19 3536.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.161643937199e+01, best bound 5.516968560245e+03, gap 10588.3943%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x1d9841a0
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3534.0160604
# Found heuristic solution: objective 4404.3094736
#
# Root relaxation: objective -5.513637e+03, 540 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5513.6374499 5513.63745  0.00%     -    1s
#
# Explored 1 nodes (540 simplex iterations) in 1.62 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5513.64 4404.31 3534.02
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.828532900620e+01, best bound 5.513637449880e+03, gap 11318.8669%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd8840081
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3531.1360604
# Found heuristic solution: objective 4401.4294736
#
# Root relaxation: objective -5.510306e+03, 523 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5510.3063395 5510.30634  0.00%     -    1s
#
# Explored 1 nodes (523 simplex iterations) in 1.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5510.31 4401.43 3531.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.495421864042e+01, best bound 5.510306339514e+03, gap 12157.5956%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x127eeb41
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3528.2560604
# Found heuristic solution: objective 4398.5494736
#
# Root relaxation: objective -5.506975e+03, 529 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5506.9752291 5506.97523  0.00%     -    1s
#
# Explored 1 nodes (529 simplex iterations) in 1.55 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5506.98 4398.55 3528.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.162310827464e+01, best bound 5.506975229148e+03, gap 13130.5718%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x3aec12dc
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3525.3760604
# Found heuristic solution: objective 4395.6694736
#
# Root relaxation: objective -5.503644e+03, 520 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5503.6441188 5503.64412  0.00%     -    1s
#
# Explored 1 nodes (520 simplex iterations) in 1.55 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5503.64 4395.67 3525.38
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.829199790885e+01, best bound 5.503644118782e+03, gap 14272.8309%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb22cf107
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3522.4960604
# Found heuristic solution: objective 4392.7894736
#
# Root relaxation: objective -5.500313e+03, 515 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5500.3130084 5500.31301  0.00%     -    1s
#
# Explored 1 nodes (515 simplex iterations) in 1.58 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5500.31 4392.79 3522.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.496088754307e+01, best bound 5.500313008416e+03, gap 15632.7614%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xc5cbf24e
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3519.6160604
# Found heuristic solution: objective 4389.9094736
#
# Root relaxation: objective -5.496982e+03, 527 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5496.9818981 5496.98190  0.00%     -    1s
#
# Explored 1 nodes (527 simplex iterations) in 1.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5496.98 4389.91 3519.62
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.162977717728e+01, best bound 5.496981898051e+03, gap 17279.1357%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x8e534219
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3516.7360604
# Found heuristic solution: objective 4387.0294736
#
# Root relaxation: objective -5.493651e+03, 522 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5493.6507877 5493.65079  0.00%     -    1s
#
# Explored 1 nodes (522 simplex iterations) in 1.56 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5493.65 4387.03 3516.74
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.829866681150e+01, best bound 5.493650787685e+03, gap 19313.1081%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xac2395e5
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3513.8560604
# Found heuristic solution: objective 4384.1494736
#
# Root relaxation: objective -5.490320e+03, 520 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5490.3196773 5490.31968  0.00%     -    1s
#
# Explored 1 nodes (520 simplex iterations) in 1.59 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5490.32 4384.15 3513.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.496755644572e+01, best bound 5.490319677319e+03, gap 21889.8158%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x205659b5
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3510.9760604
# Found heuristic solution: objective 4381.2694736
#
# Root relaxation: objective -5.486989e+03, 526 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5486.9885670 5486.98857  0.00%     -    1s
#
# Explored 1 nodes (526 simplex iterations) in 1.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5486.99 4381.27 3510.98
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.163644607993e+01, best bound 5.486988566953e+03, gap 25259.9346%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x0746bcb4
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3508.0960604
# Found heuristic solution: objective 4378.3894736
#
# Root relaxation: objective -5.483657e+03, 519 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5483.6574566 5483.65746  0.00%     -    1s
#
# Explored 1 nodes (519 simplex iterations) in 1.64 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5483.66 4378.39 3508.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.830533571415e+01, best bound 5.483657456587e+03, gap 29856.6069%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xef33e0d4
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.08s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3505.2160604
# Found heuristic solution: objective 4375.5094736
#
# Root relaxation: objective -5.480326e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5480.3263462 5480.32635  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.49 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5480.33 4375.51 3505.22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.497422534836e+01, best bound 5.480326346222e+03, gap 36498.3964%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xc7f9d512
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3502.3360604
# Found heuristic solution: objective 4372.6294736
#
# Root relaxation: objective -5.476995e+03, 524 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5476.9952359 5476.99524  0.00%     -    1s
#
# Explored 1 nodes (524 simplex iterations) in 1.62 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5477 4372.63 3502.34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.164311498258e+01, best bound 5.476995235856e+03, gap 46940.6351%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xe40b62d7
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3499.4560604
# Found heuristic solution: objective 4369.7494736
#
# Root relaxation: objective -5.473664e+03, 512 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5473.6641255 5473.66413  0.00%     -    1s
#
# Explored 1 nodes (512 simplex iterations) in 1.51 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5473.66 4369.75 3499.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.312004616795e+00, best bound 5.473664125490e+03, gap 65752.5155%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x06880a85
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3496.5760604
# Found heuristic solution: objective 4366.8694736
#
# Root relaxation: objective -5.470333e+03, 514 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5470.3330151 5470.33302  0.00%     -    1s
#
# Explored 1 nodes (514 simplex iterations) in 1.66 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5470.33 4366.87 3496.58
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.980894251011e+00, best bound 5.470333015124e+03, gap 109726.3231%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x72137398
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3493.6960604
# Found heuristic solution: objective 4363.9894736
#
# Root relaxation: objective -5.467002e+03, 525 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5467.0019048 5467.00190  0.00%     -    1s
#
# Explored 1 nodes (525 simplex iterations) in 1.57 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5467 4363.99 3493.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.649783885227e+00, best bound 5.467001904759e+03, gap 331276.8521%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x581a56c6
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.22s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3490.8160604
# Found heuristic solution: objective 4361.1094736
#
# Root relaxation: objective -5.463671e+03, 512 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5463.6707944 5463.67079  0.00%     -    3s
#
# Explored 1 nodes (512 simplex iterations) in 3.48 seconds
# Thread count was 8 (of 8 available processors)
# Solution count 3: 5463.67 4361.11 3490.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.681326480557e+00, best bound 5.463670794393e+03, gap 325061.9189%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x6baa1b13
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.12s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3487.9360604
# Found heuristic solution: objective 4358.2294736
#
# Root relaxation: objective -5.460340e+03, 531 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5460.3396840 5460.33968  0.00%     -    1s
#
# Explored 1 nodes (531 simplex iterations) in 1.68 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5460.34 4358.23 3487.94
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.012436846341e+00, best bound 5.460339684027e+03, gap 109035.8300%

# %%
#Define the range for drugs
if user_drugs_min != user_drugs_max:
    drugs_spending_delta = int((user_drugs_max - user_drugs_min)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_drugs_max,user_drugs_min,-int(drugs_spending_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_drugs_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,user_bills_max,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, user_travel_max,
                                user_drugs_min, delta,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        drugs_statement = "A better solution exists if the range of spending on drugs is from " + str(user_drugs_min) + " to " + str(new_max)
    else:
        drugs_statement = "The current solution is optimal for any value spent on drugs in the current selected range"
else:
    drugs_statement = "The current solution is optimal for any value spent on drugs in the current selected range"
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xce0c9083
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3557.0560604
# Found heuristic solution: objective 4427.3494736
#
# Root relaxation: objective -5.540286e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5540.2863328 5540.28633  0.00%     -    2s
#
# Explored 1 nodes (518 simplex iterations) in 2.81 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5540.29 4427.35 3557.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.493421193248e+01, best bound 5.540286332806e+03, gap 7293.5339%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x9a0c35c5
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.08s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3553.4560604
# Found heuristic solution: objective 4420.1494736
#
# Root relaxation: objective -5.528286e+03, 532 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5528.2863328 5528.28633  0.00%     -    1s
#
# Explored 1 nodes (532 simplex iterations) in 1.39 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5528.29 4420.15 3553.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.293421193248e+01, best bound 5.528286332806e+03, gap 8684.2306%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x9a3a0d87
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3549.8560604
# Found heuristic solution: objective 4412.9494736
#
# Root relaxation: objective -5.516286e+03, 520 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5516.2863328 5516.28633  0.00%     -    1s
#
# Explored 1 nodes (520 simplex iterations) in 1.43 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5516.29 4412.95 3549.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.093421193248e+01, best bound 5.516286332806e+03, gap 10730.2183%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x11daaf71
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.22s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3546.2560604
# Found heuristic solution: objective 4405.7494736
#
# Root relaxation: objective -5.504286e+03, 545 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5504.2863328 5504.28633  0.00%     -    2s
#
# Explored 1 nodes (545 simplex iterations) in 2.75 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5504.29 4405.75 3546.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.893421193248e+01, best bound 5.504286332806e+03, gap 14037.4027%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xf08ff28a
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3542.6560604
# Found heuristic solution: objective 4398.5494736
#
# Root relaxation: objective -5.492286e+03, 520 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    5492.2863328 5492.28633  0.00%     -    1s
#
# Explored 1 nodes (520 simplex iterations) in 1.41 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5492.29 4398.55 3542.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.693421193248e+01, best bound 5.492286332806e+03, gap 20291.4870%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb4f20ef1
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3339.0560604
# Found heuristic solution: objective 4391.3494736
#
# Root relaxation: objective -5.480286e+03, 535 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5480.2863328 5480.28633  0.00%     -    2s
#
# Explored 1 nodes (535 simplex iterations) in 2.49 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5480.29 4391.35 3339.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.493421193248e+01, best bound 5.480286332806e+03, gap 36596.1870%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xdfe0c8a3
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.13s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3335.4560604
# Found heuristic solution: objective 4384.1494736
#
# Root relaxation: objective -5.468286e+03, 543 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5468.2863328 5468.28633  0.00%     -    1s
#
# Explored 1 nodes (543 simplex iterations) in 1.48 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5468.29 4384.15 3335.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.934211932477e+00, best bound 5.468286332806e+03, gap 186263.0323%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xdf59f696
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3331.8560604
# Found heuristic solution: objective 4376.9494736
#
# Root relaxation: objective -5.456286e+03, 545 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5456.2863328 5456.28633  0.00%     -    1s
#
# Explored 1 nodes (545 simplex iterations) in 1.48 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5456.29 4376.95 3331.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.065788067523e+00, best bound 5.456286332806e+03, gap 60285.4609%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x6c57e4f0
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.21s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3328.2560604
# Found heuristic solution: objective 4369.7494736
#
# Root relaxation: objective -5.444286e+03, 544 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5444.2863328 5444.28633  0.00%     -    2s
#
# Explored 1 nodes (544 simplex iterations) in 2.77 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5444.29 4369.75 3328.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.106578806752e+01, best bound 5.444286332806e+03, gap 25944.2092%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x5bc98243
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3324.6560604
# Found heuristic solution: objective 4362.5494736
#
# Root relaxation: objective -5.432286e+03, 544 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5432.2863328 5432.28633  0.00%     -    1s
#
# Explored 1 nodes (544 simplex iterations) in 1.51 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5432.29 4362.55 3324.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.306578806752e+01, best bound 5.432286332806e+03, gap 16528.7218%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xa079a4ce
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.13s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3321.0560604
# Found heuristic solution: objective 4355.3494736
#
# Root relaxation: objective -5.420286e+03, 533 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5420.2863328 5420.28633  0.00%     -    3s
#
# Explored 1 nodes (533 simplex iterations) in 3.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5420.29 4355.35 3321.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.506578806752e+01, best bound 5.420286332806e+03, gap 12127.4971%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xe71d294d
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.08s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3317.4560604
# Found heuristic solution: objective 4348.1494736
#
# Root relaxation: objective -5.408286e+03, 559 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5408.2863328 5408.28633  0.00%     -    1s
#
# Explored 1 nodes (559 simplex iterations) in 1.46 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5408.29 4348.15 3317.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.706578806752e+01, best bound 5.408286332806e+03, gap 9577.2832%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x0e1085f3
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3313.8560604
# Found heuristic solution: objective 4340.9494736
#
# Root relaxation: objective -5.396286e+03, 553 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5396.2863328 5396.28633  0.00%     -    1s
#
# Explored 1 nodes (553 simplex iterations) in 1.56 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5396.29 4340.95 3313.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.906578806752e+01, best bound 5.396286332806e+03, gap 7913.2553%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd4d70e3f
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.24s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3310.2560604
# Found heuristic solution: objective 4333.7494736
#
# Root relaxation: objective -5.384286e+03, 529 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5384.2863328 5384.28633  0.00%     -    3s
#
# Explored 1 nodes (529 simplex iterations) in 3.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5384.29 4333.75 3310.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.106578806752e+01, best bound 5.384286332806e+03, gap 6741.8726%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xc5849bfc
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3306.6560604
# Found heuristic solution: objective 4326.5494736
#
# Root relaxation: objective -5.372286e+03, 557 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5372.2863328 5372.28633  0.00%     -    1s
#
# Explored 1 nodes (557 simplex iterations) in 1.44 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5372.29 4326.55 3306.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.306578806752e+01, best bound 5.372286332806e+03, gap 5872.5685%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x194b3ae2
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3303.0560604
# Found heuristic solution: objective 4319.3494736
#
# Root relaxation: objective -5.360286e+03, 547 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5360.2863328 5360.28633  0.00%     -    2s
#
# Explored 1 nodes (547 simplex iterations) in 2.50 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5360.29 4319.35 3303.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.050657880675e+02, best bound 5.360286332806e+03, gap 5201.8380%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd7fbe736
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.17s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3299.4560604
# Found heuristic solution: objective 4312.1494736
#
# Root relaxation: objective -5.348286e+03, 531 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5348.2863328 5348.28633  0.00%     -    1s
#
# Explored 1 nodes (531 simplex iterations) in 1.47 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5348.29 4312.15 3299.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.170657880675e+02, best bound 5.348286332806e+03, gap 4668.6160%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x495344b2
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.08s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3295.8560604
# Found heuristic solution: objective 4304.9494736
#
# Root relaxation: objective -5.336286e+03, 543 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5336.2863328 5336.28633  0.00%     -    1s
#
# Explored 1 nodes (543 simplex iterations) in 1.43 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5336.29 4304.95 3295.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.290657880675e+02, best bound 5.336286332806e+03, gap 4234.5475%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x680eab21
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.25s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3292.2560604
# Found heuristic solution: objective 4297.7494736
#
# Root relaxation: objective -5.324286e+03, 554 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5324.2863328 5324.28633  0.00%     -    3s
#
# Explored 1 nodes (554 simplex iterations) in 3.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5324.29 4297.75 3292.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.410657880675e+02, best bound 5.324286332806e+03, gap 3874.3286%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xca1ee763
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3288.6560604
# Found heuristic solution: objective 4290.5494736
#
# Root relaxation: objective -5.312286e+03, 553 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5312.2863328 5312.28633  0.00%     -    1s
#
# Explored 1 nodes (553 simplex iterations) in 1.46 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5312.29 4290.55 3288.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.530657880675e+02, best bound 5.312286332806e+03, gap 3570.5903%

# %%
#Define the range for bills
if user_bills_min != user_bills_max:
    bills_spending_delta = int((user_bills_max - user_bills_min)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_bills_max,user_bills_min,-int(bills_spending_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_bills_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,delta,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, user_travel_max,
                                user_drugs_min, user_drugs_max,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        bills_statement = "A better solution exists if the range of spending on bills is from " + str(user_bills_min) + " to " + str(new_max)
    else:
        bills_statement = "The current solution is optimal for any value spent on bills in the current selected range"
else:
    bills_statement = "The current solution is optimal for any value spent on bills in the current selected range"

# %%
#Define the range for other categories
if user_others_min != user_others_max:
    others_spending_delta = int((user_others_max - user_others_min)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_others_max,user_others_min,-int(others_spending_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_bills_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,user_bills_max,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, user_travel_max,
                                user_drugs_min, user_drugs_max,
                                user_others_min, delta,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        others_statement = "A better solution exists if the range of spending on other categories is from " + str(user_others_min) + " to " + str(new_max)
    else:
        others_statement = "The current solution is optimal for any value spent on other categories in the current selected range"
else:
    others_statement = "The current solution is optimal for any value spent on other categories in the current selected range"
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xce0c9083
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3557.0560604
# Found heuristic solution: objective 4427.3494736
#
# Root relaxation: objective -5.540286e+03, 518 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5540.2863328 5540.28633  0.00%     -    2s
#
# Explored 1 nodes (518 simplex iterations) in 2.99 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5540.29 4427.35 3557.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.493421193248e+01, best bound 5.540286332806e+03, gap 7293.5339%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x65d801c4
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.22s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3556.3360604
# Found heuristic solution: objective 4425.9094736
#
# Root relaxation: objective -5.537886e+03, 531 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5537.8863328 5537.88633  0.00%     -    1s
#
# Explored 1 nodes (531 simplex iterations) in 1.51 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5537.89 4425.91 3556.34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.253421193248e+01, best bound 5.537886332806e+03, gap 7534.8611%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x3186f5de
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3555.6160604
# Found heuristic solution: objective 4424.4694736
#
# Root relaxation: objective -5.535486e+03, 539 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5535.4863328 5535.48633  0.00%     -    1s
#
# Explored 1 nodes (539 simplex iterations) in 1.51 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5535.49 4424.47 3555.62
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.013421193248e+01, best bound 5.535486332806e+03, gap 7792.7048%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x2a2fd1ba
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.23s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3554.8960604
# Found heuristic solution: objective 4423.0294736
#
# Root relaxation: objective -5.533086e+03, 537 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5533.0863328 5533.08633  0.00%     -    3s
#
# Explored 1 nodes (537 simplex iterations) in 3.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5533.09 4423.03 3554.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.773421193248e+01, best bound 5.533086332806e+03, gap 8068.8207%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xba694998
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3554.1760604
# Found heuristic solution: objective 4421.5894736
#
# Root relaxation: objective -5.530686e+03, 512 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    5530.6863328 5530.68633  0.00%     -    1s
#
# Explored 1 nodes (512 simplex iterations) in 1.45 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5530.69 4421.59 3554.18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.533421193248e+01, best bound 5.530686332806e+03, gap 8365.2224%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb16f180d
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3553.4560604
# Found heuristic solution: objective 4420.1494736
#
# Root relaxation: objective -5.528286e+03, 538 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5528.2863328 5528.28633  0.00%     -    2s
#
# Explored 1 nodes (538 simplex iterations) in 2.62 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5528.29 4420.15 3553.46
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.293421193248e+01, best bound 5.528286332806e+03, gap 8684.2306%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x5c760c14
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.22s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3552.7360604
# Found heuristic solution: objective 4418.7094736
#
# Root relaxation: objective -5.525886e+03, 536 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5525.8863328 5525.88633  0.00%     -    1s
#
# Explored 1 nodes (536 simplex iterations) in 1.90 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5525.89 4418.71 3552.74
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.053421193248e+01, best bound 5.525886332806e+03, gap 9028.5344%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd28ab32d
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.13s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3552.0160604
# Found heuristic solution: objective 4417.2694736
#
# Root relaxation: objective -5.523486e+03, 538 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5523.4863328 5523.48633  0.00%     -    1s
#
# Explored 1 nodes (538 simplex iterations) in 1.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5523.49 4417.27 3552.02
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.813421193248e+01, best bound 5.523486332806e+03, gap 9401.2664%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xfcacfc6c
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.23s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3551.2960604
# Found heuristic solution: objective 4415.8294736
#
# Root relaxation: objective -5.521086e+03, 540 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5521.0863328 5521.08633  0.00%     -    3s
#
# Explored 1 nodes (540 simplex iterations) in 3.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5521.09 4415.83 3551.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.573421193248e+01, best bound 5.521086332806e+03, gap 9806.0992%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xbbaab7c6
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3550.5760604
# Found heuristic solution: objective 4414.3894736
#
# Root relaxation: objective -5.518686e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5518.6863328 5518.68633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.42 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5518.69 4414.39 3550.58
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.333421193248e+01, best bound 5.518686332806e+03, gap 10247.3664%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xa8fbc991
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3549.8560604
# Found heuristic solution: objective 4412.9494736
#
# Root relaxation: objective -5.516286e+03, 534 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5516.2863328 5516.28633  0.00%     -    2s
#
# Explored 1 nodes (534 simplex iterations) in 2.17 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5516.29 4412.95 3549.86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.093421193248e+01, best bound 5.516286332806e+03, gap 10730.2183%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xba5e27f3
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.24s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3549.1360604
# Found heuristic solution: objective 4411.5094736
#
# Root relaxation: objective -5.513886e+03, 534 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5513.8863328 5513.88633  0.00%     -    1s
#
# Explored 1 nodes (534 simplex iterations) in 1.83 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5513.89 4411.51 3549.14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.853421193248e+01, best bound 5.513886332806e+03, gap 11260.8239%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x56e4bb25
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3548.4160604
# Found heuristic solution: objective 4410.0694736
#
# Root relaxation: objective -5.511486e+03, 528 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5511.4863328 5511.48633  0.00%     -    1s
#
# Explored 1 nodes (528 simplex iterations) in 1.36 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5511.49 4410.07 3548.42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.613421193248e+01, best bound 5.511486332806e+03, gap 11846.6359%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x089d470a
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.23s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3547.6960604
# Found heuristic solution: objective 4408.6294736
#
# Root relaxation: objective -5.509086e+03, 524 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5509.0863328 5509.08633  0.00%     -    3s
#
# Explored 1 nodes (524 simplex iterations) in 3.35 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5509.09 4408.63 3547.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.373421193248e+01, best bound 5.509086332806e+03, gap 12496.7431%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x64e408fd
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3546.9760604
# Found heuristic solution: objective 4407.1894736
#
# Root relaxation: objective -5.506686e+03, 529 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5506.6863328 5506.68633  0.00%     -    1s
#
# Explored 1 nodes (529 simplex iterations) in 1.38 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5506.69 4407.19 3546.98
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.133421193248e+01, best bound 5.506686332806e+03, gap 13222.3450%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x8637e327
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3546.2560604
# Found heuristic solution: objective 4405.7494736
#
# Root relaxation: objective -5.504286e+03, 517 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5504.2863328 5504.28633  0.00%     -    1s
#
# Explored 1 nodes (517 simplex iterations) in 1.63 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5504.29 4405.75 3546.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.893421193248e+01, best bound 5.504286332806e+03, gap 14037.4027%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xd89dd355
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.23s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3545.5360604
# Found heuristic solution: objective 4404.3094736
#
# Root relaxation: objective -5.501886e+03, 528 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5501.8863328 5501.88633  0.00%     -    2s
#
# Explored 1 nodes (528 simplex iterations) in 2.89 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5501.89 4404.31 3545.54
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.653421193248e+01, best bound 5.501886332806e+03, gap 14959.5457%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x0a29b160
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3544.8160604
# Found heuristic solution: objective 4402.8694736
#
# Root relaxation: objective -5.499486e+03, 523 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5499.4863328 5499.48633  0.00%     -    1s
#
# Explored 1 nodes (523 simplex iterations) in 1.43 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5499.49 4402.87 3544.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.413421193248e+01, best bound 5.499486332806e+03, gap 16011.3617%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xf126bc55
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3544.0960604
# Found heuristic solution: objective 4401.4294736
#
# Root relaxation: objective -5.497086e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5497.0863328 5497.08633  0.00%     -    2s
#
# Explored 1 nodes (518 simplex iterations) in 2.52 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5497.09 4401.43 3544.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.173421193248e+01, best bound 5.497086332806e+03, gap 17222.2714%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x61ca84e3
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.21s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3543.3760604
# Found heuristic solution: objective 4399.9894736
#
# Root relaxation: objective -5.494686e+03, 524 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5494.6863328 5494.68633  0.00%     -    2s
#
# Explored 1 nodes (524 simplex iterations) in 2.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5494.69 4399.99 3543.38
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.933421193248e+01, best bound 5.494686332806e+03, gap 18631.3242%

# %%
#Define the range for user loans
if user_loans == 'Yes':
    loans_delta = int((user_loans_amount)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_loans_amount,0,-int(loans_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_bills_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,delta,user_loans_months,user_payments,user_payments_amount,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,user_bills_max,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, user_travel_max,
                                user_drugs_min, user_drugs_max,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        loans_statement = "A better solution exists if the cash advance amount is less than " + str(new_max)
    else:
        loans_statement = "The current solution is optimal for any value of cash advance taken upto " + str(user_loans_amount)
else:
    loans_statement = "NA"

# %%
#Define the range for user payments
if user_payments == 'No':
    payments_delta = int((user_payments_amount)*5/100)
    diff = 0
    new_max = 0
    for delta in range(user_payments_amount,0-int(payments_delta),-int(payments_delta)):
        model_cred_companion_new,X_new,Y_new,Z_new,Y_APR_cash_new,Y_APR_purchase_new,X_APR_purchase_new = credcompanion_calculate('Cred_Companion_bills_' + str(delta),i,j,k,C,bonus_without_cond,bonus_with_cond,apr_cash_advance,apr_purchases,
                                bonus_rewards,annual_fees,
                                user_num_cards,user_loans,user_loans_amount,user_loans_months,user_payments,delta,user_payments_months,
                                user_grocery_min,user_grocery_max,
                                user_restaurant_min,user_restaurant_max,
                                user_bills_min,user_bills_max,
                                user_fuel_min,user_fuel_max,
                                user_travel_min, user_travel_max,
                                user_drugs_min, user_drugs_max,
                                user_others_min, user_others_max,
                                income_requirement_individual, income_requirement_combined)
        model_cred_companion_new.optimize()
        for a in range(1,len(i)+1):
            if Y[str(a)].x != Y_new[str(a)].x:
                diff = 1
        if diff == 1:
            new_max = delta
            break
    if diff == 1:
        payments_statement = "A better solution exists if the credit repayment shortfall is less than " + str(new_max)
    else:
        payments_statement = "The current solution is optimal for any value of credit repayment shortfalls upto " + str(user_loans_amount)
else:
    payments_statement = "NA"
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xce0c9083
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3557.0560604
# Found heuristic solution: objective 4427.3494736
#
# Root relaxation: objective -5.540286e+03, 518 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5540.2863328 5540.28633  0.00%     -    1s
#
# Explored 1 nodes (518 simplex iterations) in 1.65 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5540.29 4427.35 3557.06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.493421193248e+01, best bound 5.540286332806e+03, gap 7293.5339%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x3ea8aec2
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 1e+04]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.12s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3420.4222574
# Found heuristic solution: objective 4271.5181604
#
# Root relaxation: objective -5.393222e+03, 549 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5393.2216743 5393.22167  0.00%     -    1s
#
# Explored 1 nodes (549 simplex iterations) in 1.77 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5393.22 4271.52 3420.42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.011371594358e+02, best bound 5.393221674265e+03, gap 2581.3651%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x7764ac69
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 9e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.09s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3283.7884544
# Found heuristic solution: objective 4115.6868472
#
# Root relaxation: objective -5.246157e+03, 541 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5246.1570157 5246.15702  0.00%     -    2s
#
# Explored 1 nodes (541 simplex iterations) in 2.65 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5246.16 4115.69 3283.79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.273401069390e+02, best bound 5.246157015725e+03, gap 1502.6625%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xc0cc2605
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 9e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3147.1546514
# Found heuristic solution: objective 3959.8555341
#
# Root relaxation: objective -5.099092e+03, 523 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5099.0923572 5099.09236  0.00%     -    1s
#
# Explored 1 nodes (523 simplex iterations) in 1.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5099.09 3959.86 3147.15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.535430544423e+02, best bound 5.099092357185e+03, gap 1024.2797%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xe595efe3
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 8e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.12s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 3010.5208483
# Found heuristic solution: objective 3804.0242209
#
# Root relaxation: objective -4.952028e+03, 537 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    4952.0276986 4952.02770  0.00%     -    2s
#
# Explored 1 nodes (537 simplex iterations) in 2.61 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4952.03 3804.02 3010.52
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.797460019456e+02, best bound 4.952027698644e+03, gap 754.1719%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xcf821f3e
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 8e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.23s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 2873.8870453
# Found heuristic solution: objective 3648.1929077
#
# Root relaxation: objective -4.804963e+03, 517 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4804.9630401 4804.96304  0.00%     -    2s
#
# Explored 1 nodes (517 simplex iterations) in 2.20 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4804.96 3648.19 2873.89
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.059489494489e+02, best bound 4.804963040104e+03, gap 580.6389%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xad38f500
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 7e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.10s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 2737.2532423
# Found heuristic solution: objective 3492.3615945
#
# Root relaxation: objective -4.657898e+03, 519 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4657.8983816 4657.89838  0.00%     -    1s
#
# Explored 1 nodes (519 simplex iterations) in 1.53 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4657.9 3492.36 2737.25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.321518969522e+02, best bound 4.657898381564e+03, gap 459.7414%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xb4327b73
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 7e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.24s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 2600.6194393
# Found heuristic solution: objective 3336.5302813
#
# Root relaxation: objective -4.508000e+03, 404 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4508.00049    0    3 3336.53028 4508.00049  35.1%     -    3s
# H    0     0                    4504.8953002 4508.00049  0.07%     -    3s
#      0     0     cutoff    0      4504.89530 4504.89530  0.00%     -    3s
#
# Cutting planes:
#   Relax-and-lift: 3
#
# Explored 1 nodes (412 simplex iterations) in 3.25 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4504.9 3336.53 2600.62
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.524164216661e+02, best bound 4.504895300234e+03, gap 372.9964%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0xede3f0dd
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 6e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.12s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 2463.9856363
# Found heuristic solution: objective 3180.6989681
#
# Root relaxation: objective -4.346770e+03, 408 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4346.76969    0    3 3180.69897 4346.76969  36.7%     -    1s
# H    0     0                    4328.4325091 4346.76969  0.42%     -    1s
#      0     0     cutoff    0      4328.43251 4328.43251  0.00%     -    1s
#
# Cutting planes:
#   Relax-and-lift: 3
#
# Explored 1 nodes (416 simplex iterations) in 1.84 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4328.43 3180.7 2463.99
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.049221236549e+03, best bound 4.328432509073e+03, gap 312.5376%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x074ce115
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 6e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 2327.3518332
# Found heuristic solution: objective 3024.8676550
#
# Root relaxation: objective -4.185539e+03, 410 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4185.53888    0    3 3024.86765 4185.53888  38.4%     -    2s
# H    0     0                    4151.9697179 4185.53888  0.81%     -    2s
#      0     0 4163.91525    0    2 4151.96972 4163.91525  0.29%     -    2s
#      0     0     cutoff    0      4151.96972 4151.96972  0.00%     -    2s
#
# Explored 1 nodes (472 simplex iterations) in 2.85 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4151.97 3024.87 2327.35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.146026051432e+03, best bound 4.151969717912e+03, gap 262.2928%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x99c8189c
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 5e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.23s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 2190.7180302
# Found heuristic solution: objective 2869.0363418
#
# Root relaxation: objective -4.024308e+03, 398 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4024.30807    0    3 2869.03634 4024.30807  40.3%     -    2s
# H    0     0                    3975.3131318 4024.30807  1.23%     -    2s
#      0     0 4004.65023    0    2 3975.31313 4004.65023  0.74%     -    2s
#      0     0 4004.65023    0    3 3975.31313 4004.65023  0.74%     -    2s
#      0     0 3975.56572    0    7 3975.31313 3975.56572  0.01%     -    2s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 6
#   Clique: 2
#
# Explored 1 nodes (522 simplex iterations) in 2.56 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3975.31 2869.04 2190.72
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.242637071388e+03, best bound 3.975565723016e+03, gap 219.9298%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x835c2296
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 5e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.11s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 2054.0842272
# Found heuristic solution: objective 2707.1650286
#
# Root relaxation: objective -3.863077e+03, 399 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3863.07726    0    3 2707.16503 3863.07726  42.7%     -    1s
# H    0     0                    3793.4818186 3863.07726  1.83%     -    1s
#      0     0 3845.38520    0    2 3793.48182 3845.38520  1.37%     -    1s
#      0     0 3845.38520    0    3 3793.48182 3845.38520  1.37%     -    1s
#      0     0 3845.38520    0    2 3793.48182 3845.38520  1.37%     -    1s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   Implied bound: 8
#
# Explored 1 nodes (510 simplex iterations) in 1.48 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3793.48 2707.17 2054.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.334073364250e+03, best bound 3.793481818643e+03, gap 184.3533%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x739ae34f
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 4e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.26s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 1917.4504242
# Found heuristic solution: objective 2541.3337154
#
# Root relaxation: objective -3.701846e+03, 398 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3701.84646    0    3 2541.33372 3701.84646  45.7%     -    3s
# H    0     0                    3607.6505055 3701.84646  2.61%     -    3s
#      0     0 3686.12018    0    2 3607.65051 3686.12018  2.18%     -    3s
#      0     0 3686.12018    0    3 3607.65051 3686.12018  2.18%     -    3s
#      0     0 3686.12018    0    2 3607.65051 3686.12018  2.18%     -    3s
#      0     0     cutoff    0      3607.65051 3607.65051  0.00%     -    3s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   Implied bound: 8
#   Flow cover: 2
#
# Explored 1 nodes (600 simplex iterations) in 3.50 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3607.65 2541.33 1917.45
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.421509657111e+03, best bound 3.607650505460e+03, gap 153.7901%
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17889 rows, 17941 columns and 35746 nonzeros
# Model fingerprint: 0x42c83602
# Model has 14332 quadratic objective terms
# Model has 894 quadratic constraints
# Variable types: 17680 continuous, 261 integer (261 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+04]
#   Objective range  [3e+01, 2e+03]
#   QObjective range [7e-03, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+05]
#   QRHS range       [1e+02, 4e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 3219 rows and 3183 columns
# Presolve time: 0.25s
# Presolved: 44785 rows, 58733 columns, 142540 nonzeros
# Presolved model has 29312 SOS constraint(s)
# Variable types: 43968 continuous, 14765 integer (14765 binary)
# Found heuristic solution: objective 1780.8166212
# Found heuristic solution: objective 2375.5024022
#
# Root relaxation: objective -3.540616e+03, 407 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3540.61565    0    3 2375.50240 3540.61565  49.0%     -    1s
# H    0     0                    3421.8191923 3540.61565  3.47%     -    1s
#      0     0 3524.51096    0    6 3421.81919 3524.51096  3.00%     -    1s
#      0     0 3524.51096    0    3 3421.81919 3524.51096  3.00%     -    1s
#      0     0 3524.51096    0    5 3421.81919 3524.51096  3.00%     -    1s
# H    0     0                    3441.4526098 3524.51096  2.41%     -    1s
#
# Cutting planes:
#   Cover: 2
#   Implied bound: 8
#   MIR: 4
#
# Explored 1 nodes (642 simplex iterations) in 1.81 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 3441.45 3421.82 2375.5 1780.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.528579367477e+03, best bound 3.441452609783e+03, gap 125.1406%

# %% [markdown]
# <a id='store_output'></a>
# ## Code Block - Store output in excel
# [Back to table of contents](#contents)

# %%
credcompanion_output(file_path,model_cred_companion,i,j,k,X,Y,C,Z,bonus_without_cond,bonus_with_cond,user_num_years,
                         annual_fees,user_loans,user_payments,user_loans_amount,apr_cash_advance,user_loans_months,Y_APR_cash,
                        Y_APR_purchase,X_APR_purchase,apr_purchases,user_payments_months,
                     travel_statement,grocery_statement,restaurant_statement,fuel_statement,drugs_statement,
                     bills_statement,others_statement,loans_statement,payments_statement)
